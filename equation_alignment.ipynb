# %%
from askem_extractions.data_model import AttributeCollection, AnchoredEntity
import json
from collections import defaultdict
import torch
import html

# %%
# extractions = AttributeCollection.from_json('extractions_page4.json')

# %%
def load_variables(path:str):
	with open(path) as f:
		data = json.load(f)

	# Sanitize the entities
	new_data = dict()
	for k, vs in data.items():
		nk = html.unescape(k) if k.startswith('&#') else k
		nvs = {html.unescape(v) if v.startswith('&#') else v for v in vs}
		new_data[nk] = list(nvs)
	
	return new_data

# load_variables('variables/page 7/eqn6.json')

# %%
def extraction_index(extractions:AttributeCollection):
	ret = defaultdict(set)
	for entity in extractions.attributes:
		entity = entity.payload
		if isinstance(entity, AnchoredEntity):

			for m in entity.mentions:
				ret[entity].add(m.name)

			for td in entity.text_descriptions:
				ret[entity].add(td.description)

	return ret

# extraction_index(extractions)

# %%
def revert_index(index):
	ret = defaultdict(list)
	for k, vs in index.items():
		for v in vs:
			ret[v].append(k)
	return ret

# revert_index(load_variables('variables/page 7/eqn6.json'))

# %%
from typing import List, Tuple
from sentence_transformers import SentenceTransformer, util


def align_texts(sources: List[str], targets: List[str], threshold: float, model) -> List[Tuple[str, str]]:

	with torch.no_grad():
		s_embs = model.encode(sources)
		t_embs = model.encode(targets)

	similarities = util.pytorch_cos_sim(s_embs, t_embs)

	indices = (similarities >= threshold).nonzero()

	ret = list()
	for ix in indices:
		ret.append((sources[ix[0]], targets[ix[1]], similarities[ix[0], ix[1]]))

	return ret

# %%
import dataclasses
from dataclasses import dataclass

@dataclass
class LinkedElement:
	element: str  	# Equation element to find an extraction for
	linked_str: str # String from an extraction linked to the equation element
	extraction: str # AnchoredEntity element linked to the equation element
	score: float    # Cosine similarity

def link_variables_to_extractions(equation_path, extractions_path):
	model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
	eqn = load_variables(equation_path)
	extractions = AttributeCollection.from_json(extractions_path)
	extractions_ix = extraction_index(extractions)

	inverted_eq = revert_index(eqn)
	invertex_ex = revert_index(extractions_ix)

	srcs = list(inverted_eq.keys())
	trgts = list(invertex_ex.keys())

	matches = align_texts(sources=srcs, targets=trgts, threshold=0.6, model=model)

	ret = list()
	for src_ix, tar_ix, sim in matches:
		for src in inverted_eq[src_ix]:
			for tgt in invertex_ex[tar_ix]:
				link = LinkedElement(
					element= src,
					extraction= tgt.model_dump(mode='json'),
					linked_str=tar_ix,
					score=sim.item()
				)
				ret.append(dataclasses.asdict(link))

	return ret

# %% [markdown]
# # Use the snippet below to link equations to extractions

# %%
link_variables_to_extractions('variables/page 4/eqn16.json', 'extractions_page4.json')
# Out:
# [{'element': 'ϕ',
#   'linked_str': 'x',
#   'extraction': {'id': {'id': 'R:889363231'},
#    'mentions': [{'id': {'id': 'T:-1661660860'},
#      'name': 'x',
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': 'The number of people who are affected as a result of visiting seafood markets is increased by h2 .\nThe parameter x generates the asymptomatic infection .\nThe periods of incubation are represented by r1 and r2 .',
#       'char_start': 650,
#       'char_end': 651,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.00007'}}],
#    'text_descriptions': [{'id': {'id': 'T:-1404947658'},
#      'description': 'parameter',
#      'grounding': [{'grounding_text': 'parameter estimation model',
#        'grounding_id': 'apollosv:00000611',
#        'source': [],
#        'score': 0.8302638530731201,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.0001'}}],
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 640,
#       'char_end': 649,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.00007'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 0.6296940445899963},
#  {'element': 't',
#   'linked_str': 't',
#   'extraction': {'id': {'id': 'E:1410321351'},
#    'mentions': [{'id': {'id': 'T:-521600559'},
#      'name': 't',
#      'extraction_source': {'page': 4,
#       'block': 10,
#       'surrounding_passage': 'Thus , the EQ .\n( 17 ) can be P td Th written as Z R tsup t sd Thds S tsup ( 1/4 ) S 0d Th exp ntsup th 0 R tsup d20Th t sd Thds th exp ntsup th 0 R R y tsup dy > 0 : 0 b exp ny th 0 t fd Thdf We can follow a similar strategy for the remaining equations in the system ( 15 ) to prove D td Th > 0 for all t > 0 .\nFor further assertion , consider that the initial conditions satisfy 0 < S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 6 P TD th .',
#       'char_start': 573,
#       'char_end': 574,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.001005'}}],
#    'text_descriptions': [],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 1.0000001192092896},
#  {'element': 't',
#   'linked_str': 'SUP T',
#   'extraction': {'id': {'id': 'E:-1207175500'},
#    'mentions': [{'id': {'id': 'T:-748193977'},
#      'name': 'SUP T',
#      'extraction_source': {'page': 4,
#       'block': 10,
#       'surrounding_passage': 'F G : Tsup ( 1/4 ) SUP T > 0 : D TD th > 0 Thus , Tsup > 0 .\nThe first equation of the model ( 15 ) leads to the following relation dS td Th ( 1/4 ) b nS td Th t td ThS td Th ( 1/4 ) b S td Th n th t td Th d Th ; d17Th dt d Th where t td Th ( 1/4 ) h1 I td Thth / A td Th th h2M td Th .',
#       'char_start': 16,
#       'char_end': 21,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.001089'}}],
#    'text_descriptions': [],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'Meruvax I',
#      'grounding_id': 'vo:0003109',
#      'source': [],
#      'score': 0.7846900224685669,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.001102'}}],
#    'data_columns': None},
#   'score': 0.6814061999320984},
#  {'element': 't',
#   'linked_str': 'T',
#   'extraction': {'id': {'id': 'E:-334254679'},
#    'mentions': [{'id': {'id': 'T:1535608579'},
#      'name': 'T',
#      'extraction_source': {'page': 3,
#       'block': 4,
#       'surrounding_passage': 'Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .\nNotice that the above general operators are linear , so we have CDa CDa CDa d d3Th 0 Th ( 1/4 ) k 0 t kf td Th th lg td Th t f td Th th l 0 t g td Th ; .',
#       'char_start': 204,
#       'char_end': 205,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.008136'}}],
#    'text_descriptions': [{'id': {'id': 'T:-1842213138'},
#      'description': 'general kernel loc',
#      'grounding': [],
#      'extraction_source': {'page': 3,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 225,
#       'char_end': 243,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.008136'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 1.0000001192092896},
#  {'element': 't',
#   'linked_str': 'd',
#   'extraction': {'id': {'id': 'R:-1822270571'},
#    'mentions': [{'id': {'id': 'T:-1157852791'},
#      'name': 'd',
#      'extraction_source': {'page': 7,
#       'block': 2,
#       'surrounding_passage': 'Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .',
#       'char_start': 36,
#       'char_end': 37,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.009857'}}],
#    'text_descriptions': [{'id': {'id': 'T:1731739390'},
#      'description': 'Th d d Th ds',
#      'grounding': [],
#      'extraction_source': {'page': 7,
#       'block': 2,
#       'surrounding_passage': None,
#       'char_start': 23,
#       'char_end': 35,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.009857'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 0.6234027743339539},
#  {'element': 'P',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'E:-957951765'},
#    'mentions': [{'id': {'id': 'T:-1067984383'},
#      'name': 'b',
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': 'The infected people with clinically symptomatic or without clinical symptoms , as well as the infected individuals of seafood markets I td Th ; A td Th ; M td Th d Th can infect the susceptible people to the disease , which is shown as t td Th .\nFor susceptible individuals , the corresponding birth rate is b , and the human mortality rate can be measured by n. Healthy people would become infectious after exposure to the infected and asymptomatically infected individuals at the rate h1 , where as the transmissibility factor is denoted by / .\nThe number of people who are affected as a result of visiting seafood markets is increased by h2 .',
#       'char_start': 302,
#       'char_end': 303,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000011'}}],
#    'text_descriptions': [{'id': {'id': 'T:1524698050'},
#      'description': 'corresponding birth rate',
#      'grounding': [{'grounding_text': 'Noise Equivalent Count Rate',
#        'grounding_id': 'ncit:C94941',
#        'source': [],
#        'score': 0.7655113339424133,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.000038'}}],
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 274,
#       'char_end': 298,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000011'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.000022'}}],
#    'data_columns': None},
#   'score': 0.6303893327713013},
#  {'element': 'P',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'R:458610627'},
#    'mentions': [{'id': {'id': 'T:560977112'},
#      'name': 'b',
#      'extraction_source': {'page': 5,
#       'block': 1,
#       'surrounding_passage': 'd Th .\nHence , n 1 ent Furthermore , either P td Th tends asymptomatically toward b n or the solution enters Z in a finite time if we have P 0d Th < b n and sithsa M 0d Th < b .\nThis means that all the solutions in R7th are n sm attracted by the region given by Z. h .',
#       'char_start': 563,
#       'char_end': 564,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.002251'}}],
#    'text_descriptions': [{'id': {'id': 'T:1981491033'},
#      'description': 'sithsa M 0d Th <',
#      'grounding': [],
#      'extraction_source': {'page': 5,
#       'block': 1,
#       'surrounding_passage': None,
#       'char_start': 546,
#       'char_end': 562,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.002251'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.002265'}}],
#    'data_columns': None},
#   'score': 0.6303893327713013},
#  {'element': 'P',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'E:-656629184'},
#    'mentions': [{'id': {'id': 'T:1776527982'},
#      'name': 'b',
#      'extraction_source': {'page': 9,
#       'block': 11,
#       'surrounding_passage': 'According to these results , one can see that the best fractional order is 0:99 for all three cases .\nFig. 4 displays the fractional simulations by considering the ( a ) power-law , ( b ) Mittag-Leffler , and ( c ) exponential kernels versus the real reported cases of COVID-19 in China .\nThe results illustrate the improvement which is made by applying the new general fractional model to follow the real data better than the classical integer-order model .',
#       'char_start': 2199,
#       'char_end': 2200,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.004819'}}],
#    'text_descriptions': [{'id': {'id': 'T:-585538958'},
#      'description': ') power-law',
#      'grounding': [],
#      'extraction_source': {'page': 9,
#       'block': 11,
#       'surrounding_passage': None,
#       'char_start': 2185,
#       'char_end': 2196,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.004819'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.004832'}}],
#    'data_columns': None},
#   'score': 0.6303893327713013},
#  {'element': 'P',
#   'linked_str': 'P',
#   'extraction': {'id': {'id': 'E:939845203'},
#    'mentions': [{'id': {'id': 'T:-1157437001'},
#      'name': 'P',
#      'extraction_source': {'page': 4,
#       'block': 8,
#       'surrounding_passage': 'D TD th ( 1/4 ) s TD th ; v TD th ; i TD th ; A TD th ; K TD th ; U TD th ; R TD th ; M TD th D th ; D th P 0 Be the Nonand D 0d th ( 1/4 ) S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 ; M0 negative initial state vector .\nThen the model ( 15 ) has a nonnegative solution for any time t > 0 .',
#       'char_start': 96,
#       'char_end': 97,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000594'}}],
#    'text_descriptions': [{'id': {'id': 'T:175687440'},
#      'description': 'Nonand D 0d',
#      'grounding': [{'grounding_text': 'Meruvax I',
#        'grounding_id': 'vo:0003109',
#        'source': [],
#        'score': 0.7801608443260193,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.000621'}}],
#      'extraction_source': {'page': 4,
#       'block': 8,
#       'surrounding_passage': None,
#       'char_start': 107,
#       'char_end': 118,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000594'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'P phosphoprotein',
#      'grounding_id': 'vo:0011169',
#      'source': [],
#      'score': 0.8038516044616699,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.000605'}}],
#    'data_columns': None},
#   'score': 0.9999995231628418},
#  {'element': 'P',
#   'linked_str': 'P.O',
#   'extraction': {'id': {'id': 'E:681378180'},
#    'mentions': [{'id': {'id': 'T:-1402121606'},
#      'name': 'P.O',
#      'extraction_source': {'page': 1,
#       'block': 4,
#       'surrounding_passage': 'A Department of Mathematics , Faculty of Arts and Sciences , C Ankaya University , 06530 Ankara , Turkey B Institute of Space Sciences , P.O .\nBox , MG-23 , R 76900 Magurele-Bucharest , Romania C Department of Medical Research , China Medical University Hospital , China Medical University , Taichung , Taiwan D Department of Mathematics , Faculty of Mathematical Science and Statistics , University of Birjand , Birjand , Iran E Department of Electrical Engineering , University of Bojnord , P.O .',
#       'char_start': 132,
#       'char_end': 135,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.00615'}}],
#    'text_descriptions': [{'id': {'id': 'T:1695571457'},
#      'description': 'Institute of Space Sciences',
#      'grounding': [{'grounding_text': 'Division of Basic Sciences',
#        'grounding_id': 'ncit:C19215',
#        'source': [],
#        'score': 0.8283291459083557,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.006183'}}],
#      'extraction_source': {'page': 1,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 103,
#       'char_end': 130,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.00615'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 0.6599332094192505},
#  {'element': 'P',
#   'linked_str': 'P.O',
#   'extraction': {'id': {'id': 'E:1355897579'},
#    'mentions': [{'id': {'id': 'T:1959900871'},
#      'name': 'P.O',
#      'extraction_source': {'page': 1,
#       'block': 4,
#       'surrounding_passage': "A Department of Mathematics , Faculty of Arts and Sciences , C Ankaya University , 06530 Ankara , Turkey B Institute of Space Sciences , P.O .\nBox , MG-23 , R 76900 Magurele-Bucharest , Romania C Department of Medical Research , China Medical University Hospital , China Medical University , Taichung , Taiwan D Department of Mathematics , Faculty of Mathematical Science and Statistics , University of Birjand , Birjand , Iran E Department of Electrical Engineering , University of Bojnord , P.O .\nBox , 94531-1339 , Bojnord , Iran F Islamic Azad University , Tehran Science and Research Branch , Tehran , Iran G Instituto de Matema'ticas , Universidade de Santiago de Compostela , 15782 Santiago de Compostela , Spain .",
#       'char_start': 474,
#       'char_end': 477,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.006677'}}],
#    'text_descriptions': [{'id': {'id': 'T:-1756238745'},
#      'description': 'University of Bojnord',
#      'grounding': [{'grounding_text': 'University of Queensland',
#        'grounding_id': 'vo:0004985',
#        'source': [],
#        'score': 0.8623424768447876,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.006713'}}],
#      'extraction_source': {'page': 1,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 451,
#       'char_end': 472,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.006677'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 0.6599332094192505},
#  {'element': 'P',
#   'linked_str': 'd',
#   'extraction': {'id': {'id': 'R:-1822270571'},
#    'mentions': [{'id': {'id': 'T:-1157852791'},
#      'name': 'd',
#      'extraction_source': {'page': 7,
#       'block': 2,
#       'surrounding_passage': 'Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .',
#       'char_start': 36,
#       'char_end': 37,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.009857'}}],
#    'text_descriptions': [{'id': {'id': 'T:1731739390'},
#      'description': 'Th d d Th ds',
#      'grounding': [],
#      'extraction_source': {'page': 7,
#       'block': 2,
#       'surrounding_passage': None,
#       'char_start': 23,
#       'char_end': 35,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.009857'}}],
#    'value_descriptions': [],
#    'groundings': [],
#    'data_columns': None},
#   'score': 0.6741349697113037},
#  {'element': 'A',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'E:-957951765'},
#    'mentions': [{'id': {'id': 'T:-1067984383'},
#      'name': 'b',
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': 'The infected people with clinically symptomatic or without clinical symptoms , as well as the infected individuals of seafood markets I td Th ; A td Th ; M td Th d Th can infect the susceptible people to the disease , which is shown as t td Th .\nFor susceptible individuals , the corresponding birth rate is b , and the human mortality rate can be measured by n. Healthy people would become infectious after exposure to the infected and asymptomatically infected individuals at the rate h1 , where as the transmissibility factor is denoted by / .\nThe number of people who are affected as a result of visiting seafood markets is increased by h2 .',
#       'char_start': 302,
#       'char_end': 303,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000011'}}],
#    'text_descriptions': [{'id': {'id': 'T:1524698050'},
#      'description': 'corresponding birth rate',
#      'grounding': [{'grounding_text': 'Noise Equivalent Count Rate',
#        'grounding_id': 'ncit:C94941',
#        'source': [],
#        'score': 0.7655113339424133,
#        'provenance': {'method': 'SKEMA-TR-Embedding',
#         'timestamp': '2023-09-15T20:32:29.000038'}}],
#      'extraction_source': {'page': 4,
#       'block': 4,
#       'surrounding_passage': None,
#       'char_start': 274,
#       'char_end': 298,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.000011'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.000022'}}],
#    'data_columns': None},
#   'score': 0.6357161402702332},
#  {'element': 'A',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'R:458610627'},
#    'mentions': [{'id': {'id': 'T:560977112'},
#      'name': 'b',
#      'extraction_source': {'page': 5,
#       'block': 1,
#       'surrounding_passage': 'd Th .\nHence , n 1 ent Furthermore , either P td Th tends asymptomatically toward b n or the solution enters Z in a finite time if we have P 0d Th < b n and sithsa M 0d Th < b .\nThis means that all the solutions in R7th are n sm attracted by the region given by Z. h .',
#       'char_start': 563,
#       'char_end': 564,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.002251'}}],
#    'text_descriptions': [{'id': {'id': 'T:1981491033'},
#      'description': 'sithsa M 0d Th <',
#      'grounding': [],
#      'extraction_source': {'page': 5,
#       'block': 1,
#       'surrounding_passage': None,
#       'char_start': 546,
#       'char_end': 562,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.002251'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.002265'}}],
#    'data_columns': None},
#   'score': 0.6357161402702332},
#  {'element': 'A',
#   'linked_str': 'b',
#   'extraction': {'id': {'id': 'E:-656629184'},
#    'mentions': [{'id': {'id': 'T:1776527982'},
#      'name': 'b',
#      'extraction_source': {'page': 9,
#       'block': 11,
#       'surrounding_passage': 'According to these results , one can see that the best fractional order is 0:99 for all three cases .\nFig. 4 displays the fractional simulations by considering the ( a ) power-law , ( b ) Mittag-Leffler , and ( c ) exponential kernels versus the real reported cases of COVID-19 in China .\nThe results illustrate the improvement which is made by applying the new general fractional model to follow the real data better than the classical integer-order model .',
#       'char_start': 2199,
#       'char_end': 2200,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.004819'}}],
#    'text_descriptions': [{'id': {'id': 'T:-585538958'},
#      'description': ') power-law',
#      'grounding': [],
#      'extraction_source': {'page': 9,
#       'block': 11,
#       'surrounding_passage': None,
#       'char_start': 2185,
#       'char_end': 2196,
#       'document_reference': {'id': 'Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'}},
#      'provenance': {'method': 'Skema TR Pipeline rules',
#       'timestamp': '2023-09-15T20:32:29.004819'}}],
#    'value_descriptions': [],
#    'groundings': [{'grounding_text': 'AIDSVAX B/B',
#      'grounding_id': 'vo:0000405',
#      'source': [],
#      'score': 0.8989673256874084,
#      'provenance': {'method': 'SKEMA-TR-Embedding',
#       'timestamp': '2023-09-15T20:32:29.004832'}}],
#    'data_columns': None},
#   'score': 0.6357161402702332}]

# %% [markdown]
# # Use the snippet below to compare two strings and get cosine similarity

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

def compare_similarities(a: str, b: str, model) -> float:

	with torch.no_grad():
		s_embs = model.encode(a)
		t_embs = model.encode(b)

	similarities = util.pytorch_cos_sim(s_embs, t_embs)

	return similarities.item()

print(compare_similarities("alpha", "α", model))
print(compare_similarities("initial rate", "R0", model))
# Out:
# 0.9094832539558411
# 0.2623198330402374
