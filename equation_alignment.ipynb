# %%
from askem_extractions.data_model import AttributeCollection, AnchoredEntity
import json
from collections import defaultdict
import torch
import html
# Out:
# /Users/enoriega/.pyenv/versions/miniconda3-latest/envs/skema-dev/lib/python3.8/site-packages/pydantic/_internal/_config.py:261: UserWarning: Valid config keys have changed in V2:
# * 'schema_extra' has been renamed to 'json_schema_extra'
#   warnings.warn(message, UserWarning)

# %%
extractions = AttributeCollection.from_json('extractions_page4.json')

# %%
def load_variables(path:str):
	with open(path) as f:
		data = json.load(f)

	# Sanitize the entities
	new_data = dict()
	for k, vs in data.items():
		nk = html.unescape(k) if k.startswith('&#') else k
		nvs = {html.unescape(v) if v.startswith('&#') else v for v in vs}
		new_data[nk] = list(nvs)
	
	return new_data

load_variables('variables/page 7/eqn6.json')
# Out:
# {'β': ['β', 'beta'],
#  'σ': ['sigma', 'σ'],
#  'r': ['r'],
#  'I_t': ['I_t', 'I_{t}'],
#  'σ_it^t': ['σ_it^t', 'σ_{it^{t}}'],
#  't': ['t'],
#  'G': ['G'],
#  'S': ['S'],
#  'i': ['i'],
#  'p': ['p'],
#  'N': ['N'],
#  'S_t': ['S_{t}', 'S_t'],
#  'I': ['I']}

# %%
def extraction_index(extractions:AttributeCollection):
	ret = defaultdict(set)
	for entity in extractions.attributes:
		entity = entity.payload
		if isinstance(entity, AnchoredEntity):

			for m in entity.mentions:
				ret[entity].add(m.name)

			for td in entity.text_descriptions:
				ret[entity].add(td.description)

	return ret

extraction_index(extractions)
# Out:
# defaultdict(set,
#             {AnchoredEntity(id=ID(id='R:22946840'), mentions=[Mention(id=ID(id='T:1309853609'), name='AIDS', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='Mathematical models can help public health interventions by showing the likely outcome of an epidemic .\nIn the book [ 1 ] , the authors covered the concept of mathematical models in epidemiology for certain diseases such as HIV / AIDS , influenza , dengue fever , Zika virus , etc.\nThe paper [ 2 ] investigated the impact of case-area targeted intervention and its effect on reducing cholera transmission .', char_start=1503, char_end=1507, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994331)))], text_descriptions=[TextDescription(id=ID(id='T:109968174'), description='influenza', grounding=[Grounding(grounding_text='H1N1 Influenza vaccine', grounding_id='vo:0000578', source=[], score=0.8757119178771973, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994455)))], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=1509, char_end=1518, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994331)))], value_descriptions=[], groundings=[Grounding(grounding_text='AIDS Population', grounding_id='ncit:C18620', source=[], score=0.7728735208511353, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994357)))], data_columns=None): {'AIDS',
#               'influenza'},
#              AnchoredEntity(id=ID(id='R:240147287'), mentions=[Mention(id=ID(id='T:969354926'), name='Wuhan', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='In [ 7 ] , the COVID-19 dynamics were analyzed by using three numerical schemes in the frameworks of singular and nonsingular fractional operators .\nIn [ 8] , the authors developed a model that synthesized the indicators extracted from the outbreak in Wuhan ( China ) .\nThe COVID-19 dynamics in Italy were analyzed in [ 9 ] by the concept of mathematical modelling .', char_start=2280, char_end=2285, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994519)))], text_descriptions=[TextDescription(id=ID(id='T:2052643501'), description='China', grounding=[Grounding(grounding_text='Chinese', grounding_id='ncit:C43391', source=[], score=0.7607220411300659, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994560)))], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=2287, char_end=2292, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994519)))], value_descriptions=[], groundings=[], data_columns=None): {'China',
#               'Wuhan'},
#              AnchoredEntity(id=ID(id='R:-1780710942'), mentions=[Mention(id=ID(id='T:1649670655'), name='concept of mathematical modelling', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='In [ 8] , the authors developed a model that synthesized the indicators extracted from the outbreak in Wuhan ( China ) .\nThe COVID-19 dynamics in Italy were analyzed in [ 9 ] by the concept of mathematical modelling .\nBased on Tennessee State data in the United States , the study [ 10 ] presented a fractional compartmental model for the spread of COVID-19 .', char_start=2354, char_end=2387, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994684)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-1261738014'), value=Value(amount='9', grounding=[], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=2344, char_end=2345, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994684)))], groundings=[], data_columns=None): {'concept of mathematical modelling'},
#              AnchoredEntity(id=ID(id='R:1548084014'), mentions=[Mention(id=ID(id='T:844129574'), name='use of non-standard computations to study the stochastic pandemic model of COVID-19', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='To eradicate COVID-19 , nonpharmaceutical interventions based on mathematical modelling were introduced in [ 21 ] , and the threshold conditions were studied for the disease-free steady-states .\nBased on parametric perturbations and transition probabilities , the authors in [ 22 ] discussed the use of non standard computations to study the stochastic pandemic model of COVID-19 .\nThe paper [ 23 ] also examined the bats-hosts-reservoir-people COVID-19 model and used a variational iteration method to derive its corresponding approximate solution .', char_start=4640, char_end=4723, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994832)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-1807392827'), value=Value(amount='22', grounding=[], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=4622, char_end=4624, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994832)))], groundings=[Grounding(grounding_text='FDA_Table', grounding_id='ncit:P317', source=[], score=0.8392574787139893, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994845)))], data_columns=None): {'use of non-standard computations to study the stochastic pandemic model of COVID-19'},
#              AnchoredEntity(id=ID(id='R:-997499173'), mentions=[Mention(id=ID(id='T:362515527'), name='simulation of COVID-19 transmission', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='Based on Tennessee State data in the United States , the study [ 10 ] presented a fractional compartmental model for the spread of COVID-19 .\nIn [ 11 ] , the simulation of COVID-19 transmission in a northeastern state of Brazil was investigated through a mathematical model .\nThe work [ 12 ] studied a new model of COVID-19 by not only applying the real-world data from Pakistan but also using the stability theory of differential equations .', char_start=2540, char_end=2575, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994891)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-2076106311'), value=Value(amount='11', grounding=[], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=2531, char_end=2533, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994891)))], groundings=[Grounding(grounding_text='simulation of disease', grounding_id='apollosv:00000042', source=[], score=0.8346294164657593, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 994903)))], data_columns=None): {'simulation of COVID-19 transmission'},
#              AnchoredEntity(id=ID(id='R:-1352781355'), mentions=[Mention(id=ID(id='T:2133477013'), name='impact of case-area targeted intervention', extraction_source=TextExtraction(page=1, block=10, surrounding_passage='In the book [ 1 ] , the authors covered the concept of mathematical models in epidemiology for certain diseases such as HIV / AIDS , influenza , dengue fever , Zika virus , etc.\nThe paper [ 2 ] investigated the impact of case-area targeted intervention and its effect on reducing cholera transmission .\nThe other study [ 3 ] introduced vaccines to susceptible people in order to control Ebola disease spread .', char_start=1582, char_end=1623, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 995088)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-900639349'), value=Value(amount='2', grounding=[], extraction_source=TextExtraction(page=1, block=10, surrounding_passage=None, char_start=1562, char_end=1563, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 995088)))], groundings=[Grounding(grounding_text='simulation of organism awaiting effect of control measure', grounding_id='apollosv:00000059', source=[], score=0.7651695013046265, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 995101)))], data_columns=None): {'impact of case-area targeted intervention'},
#              AnchoredEntity(id=ID(id='R:1713602713'), mentions=[Mention(id=ID(id='T:688598702'), name='ds', extraction_source=TextExtraction(page=3, block=6, surrounding_passage='Z T d Th ds ; d9Th tDa f sd ThKR s t Tf td Th ( 1/4 ) d dt t and the right-sided Riemann-Liouville fractional integral would be described as .', char_start=9, char_end=11, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 995989)))], text_descriptions=[TextDescription(id=ID(id='T:836464404'), description='Z T d Th', grounding=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7576173543930054, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996027)))], extraction_source=TextExtraction(page=3, block=6, surrounding_passage=None, char_start=0, char_end=8, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 995989)))], value_descriptions=[], groundings=[], data_columns=None): {'Z T d Th',
#               'ds'},
#              AnchoredEntity(id=ID(id='R:-1106686363'), mentions=[Mention(id=ID(id='T:-2101005978'), name='s', extraction_source=TextExtraction(page=3, block=6, surrounding_passage='Z T d Th ds ; d9Th tDa f sd ThKR s t Tf td Th ( 1/4 ) d dt t and the right-sided Riemann-Liouville fractional integral would be described as .', char_start=32, char_end=33, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996069)))], text_descriptions=[TextDescription(id=ID(id='T:-493595611'), description='tDa f sd ThKR', grounding=[], extraction_source=TextExtraction(page=3, block=6, surrounding_passage=None, char_start=18, char_end=31, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996069)))], value_descriptions=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996081)))], data_columns=None): {'s',
#               'tDa f sd ThKR'},
#              AnchoredEntity(id=ID(id='R:147314443'), mentions=[Mention(id=ID(id='T:-149583038'), name='Th', extraction_source=TextExtraction(page=3, block=6, surrounding_passage='Z T d Th ds ; d9Th tDa f sd ThKR s t Tf td Th ( 1/4 ) d dt t and the right-sided Riemann-Liouville fractional integral would be described as .', char_start=42, char_end=44, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996128)))], text_descriptions=[TextDescription(id=ID(id='T:1378639789'), description='Tf td', grounding=[], extraction_source=TextExtraction(page=3, block=6, surrounding_passage=None, char_start=36, char_end=41, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996128)))], value_descriptions=[], groundings=[], data_columns=None): {'Tf td',
#               'Th'},
#              AnchoredEntity(id=ID(id='R:-1629500135'), mentions=[Mention(id=ID(id='T:-1747195779'), name='s', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .', char_start=38, char_end=39, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996195)))], text_descriptions=[TextDescription(id=ID(id='T:471952483'), description='sd ThsDa f sd Th0', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=20, char_end=37, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996195)))], value_descriptions=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996206)))], data_columns=None): {'s',
#               'sd ThsDa f sd Th0'},
#              AnchoredEntity(id=ID(id='R:-1270356868'), mentions=[Mention(id=ID(id='T:471962541'), name='g', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .', char_start=18, char_end=19, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996283)))], text_descriptions=[TextDescription(id=ID(id='T:1769299146'), description='Z T T CDa d12Th', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=2, char_end=17, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996283)))], value_descriptions=[], groundings=[Grounding(grounding_text='Education-Subcommittee G', grounding_id='ncit:C19510', source=[], score=1.0, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996295)))], data_columns=None): {'Z T T CDa d12Th',
#               'g'},
#              AnchoredEntity(id=ID(id='R:1588428310'), mentions=[Mention(id=ID(id='T:638053137'), name='td', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='( 7 ) becomes the Riemann-Liouville Integral [ 36 ] .\nSec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .', char_start=577, char_end=579, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996363)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-1086066659'), value=Value(amount='M 0d Th (1/4', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=706, char_end=718, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 996363)))], groundings=[], data_columns=None): {'td'},
#              AnchoredEntity(id=ID(id='R:-103118657'), mentions=[Mention(id=ID(id='T:844238773'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='( 7 ) becomes the Riemann-Liouville Integral [ 36 ] .\nSec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .', char_start=580, char_end=582, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997168)))], text_descriptions=[TextDescription(id=ID(id='T:-2132649580'), description='kernel KL td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=567, char_end=579, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997168)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'kernel KL td'},
#              AnchoredEntity(id=ID(id='E:820899788'), mentions=[Mention(id=ID(id='T:-1283353421'), name='ond', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='( 7 ) becomes the Riemann-Liouville Integral [ 36 ] .\nSec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .', char_start=558, char_end=561, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997282)))], text_descriptions=[TextDescription(id=ID(id='T:-1011376642'), description='M ad Th 1a Ea 1a', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=589, char_end=605, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997282)))], value_descriptions=[], groundings=[], data_columns=None): {'M ad Th 1a Ea 1a',
#               'ond'},
#              AnchoredEntity(id=ID(id='R:1234863594'), mentions=[Mention(id=ID(id='T:1944949929'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='( 7 ) becomes the Riemann-Liouville Integral [ 36 ] .\nSec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .', char_start=627, char_end=629, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997386)))], text_descriptions=[TextDescription(id=ID(id='T:1200881736'), description='ad', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=624, char_end=626, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997386)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'ad'},
#              AnchoredEntity(id=ID(id='R:519813480'), mentions=[Mention(id=ID(id='T:244684773'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .\nConsequently , the eqs .', char_start=189, char_end=191, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997496)))], text_descriptions=[TextDescription(id=ID(id='T:1446748321'), description='general kernel KL td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=168, char_end=188, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997496)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'general kernel KL td'},
#              AnchoredEntity(id=ID(id='R:1243452913'), mentions=[Mention(id=ID(id='T:-1120810422'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .\nConsequently , the eqs .', char_start=262, char_end=264, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997569)))], text_descriptions=[TextDescription(id=ID(id='T:1574275725'), description='power function ML td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=241, char_end=261, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997569)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'power function ML td'},
#              AnchoredEntity(id=ID(id='R:1626499275'), mentions=[Mention(id=ID(id='T:1785175400'), name='AB', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Sec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .', char_start=915, char_end=917, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997648)))], text_descriptions=[TextDescription(id=ID(id='T:367050252'), description='Atangana-Baleanu', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=897, char_end=913, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997648)))], value_descriptions=[], groundings=[], data_columns=None): {'AB',
#               'Atangana-Baleanu'},
#              AnchoredEntity(id=ID(id='R:1299460863'), mentions=[Mention(id=ID(id='T:982808160'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Sec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .', char_start=830, char_end=832, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997760)))], text_descriptions=[TextDescription(id=ID(id='T:-2037620983'), description='d13Th ML td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=818, char_end=829, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997760)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'd13Th ML td'},
#              AnchoredEntity(id=ID(id='R:-221943035'), mentions=[Mention(id=ID(id='T:-592467273'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Sec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .', char_start=810, char_end=812, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997925)))], text_descriptions=[TextDescription(id=ID(id='T:715110189'), description='kernel ML td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=797, char_end=809, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 997925)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'kernel ML td'},
#              AnchoredEntity(id=ID(id='R:1339987749'), mentions=[Mention(id=ID(id='T:1388200444'), name='ta1', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Sec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .', char_start=877, char_end=880, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998053)))], text_descriptions=[TextDescription(id=ID(id='T:-17112329'), description='M ad ThC ad Th', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=862, char_end=876, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998053)))], value_descriptions=[], groundings=[], data_columns=None): {'M ad ThC ad Th',
#               'ta1'},
#              AnchoredEntity(id=ID(id='R:353548395'), mentions=[Mention(id=ID(id='T:-1129430987'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Sec a would be considered in ond , the kernel KL td Th ( 1/4 ) M ad Th 1a Ea 1a ta which Ea and M ad Th are , respectively , the Mittag-Leffler and normalization functions such that M 0d Th ( 1/4 ) M 1d Th ( 1/4 ) 1 .\nThen by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .', char_start=856, char_end=858, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998207)))], text_descriptions=[TextDescription(id=ID(id='T:526406314'), description='M ad Th d td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=843, char_end=855, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998207)))], value_descriptions=[], groundings=[], data_columns=None): {'M ad Th d td',
#               'Th'},
#              AnchoredEntity(id=ID(id='R:-1481987224'), mentions=[Mention(id=ID(id='T:30889312'), name='th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1116, char_end=1118, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998381)))], text_descriptions=[TextDescription(id=ID(id='T:-996511073'), description='sd Th ds', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1107, char_end=1115, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998381)))], value_descriptions=[], groundings=[], data_columns=None): {'sd Th ds',
#               'th'},
#              AnchoredEntity(id=ID(id='E:183768893'), mentions=[Mention(id=ID(id='T:-660157535'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1270, char_end=1272, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998476)))], text_descriptions=[TextDescription(id=ID(id='T:1384632966'), description='kernel', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1239, char_end=1245, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998476)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'kernel'},
#              AnchoredEntity(id=ID(id='R:1129324564'), mentions=[Mention(id=ID(id='T:-660157535'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1270, char_end=1272, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998591)))], text_descriptions=[TextDescription(id=ID(id='T:77390180'), description='exposetting KL td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1252, char_end=1269, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998591)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'exposetting KL td'},
#              AnchoredEntity(id=ID(id='E:809337677'), mentions=[Mention(id=ID(id='T:-660157535'), name='Th', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1270, char_end=1272, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998732)))], text_descriptions=[TextDescription(id=ID(id='T:77390180'), description='exposetting KL td', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1252, char_end=1269, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998732)))], value_descriptions=[], groundings=[], data_columns=None): {'Th',
#               'exposetting KL td'},
#              AnchoredEntity(id=ID(id='R:-1431067030'), mentions=[Mention(id=ID(id='T:1200513543'), name='ThC', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1134, char_end=1137, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998827)))], text_descriptions=[TextDescription(id=ID(id='T:-882717053'), description='0Da t M ad', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1123, char_end=1133, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998827)))], value_descriptions=[], groundings=[], data_columns=None): {'0Da t M ad',
#               'ThC'},
#              AnchoredEntity(id=ID(id='R:-1123574289'), mentions=[Mention(id=ID(id='T:-823977784'), name='f', extraction_source=TextExtraction(page=3, block=8, surrounding_passage='Then by applying the Laplace transformation , we achieve the kernel ML td Th as a d13Th ML td Th ( 1/4 ) 1 a M ad Th d td Th th M ad ThC ad Th ta1 : Therefore , the Atangana-Baleanu ( AB ) - Caputo and ABRiemann-Liouville derivatives are , respectively , recovered from the Eqs .\n( 1 ) and ( 2 ) , and the AB fractional integral is acquired by [ 37 ] Z t a d14Th f td Th ( 1/4 ) d t s Tha1f sd Th ds th 1 a 0Da t M ad ThC ad Th M ad Th f td Th : 0 Finally , the Caputo-Fabrizio ( CF ) derivative is formulated by in which the kernel is an exposetting KL td Th ( 1/4 ) M ad Th 1a t 1a exp a nential function .\nFurthermore , M ad th would be the normalization function satisfying m 0d th ( 1/4 ) m 1d th ( 1/4 ) 1 [ 38-40 ] .', char_start=1152, char_end=1153, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998922)))], text_descriptions=[TextDescription(id=ID(id='T:-2088013117'), description='ad Th M ad Th', grounding=[], extraction_source=TextExtraction(page=3, block=8, surrounding_passage=None, char_start=1138, char_end=1151, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998922)))], value_descriptions=[], groundings=[Grounding(grounding_text='rFP-RPV-H/F', grounding_id='vo:0004752', source=[], score=1.0, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 28, 998933)))], data_columns=None): {'ad Th M ad Th',
#               'f'},
# ...
#               'interpolation polynomial bF Skth1 sd'},
#              AnchoredEntity(id=ID(id='R:-1844024980'), mentions=[Mention(id=ID(id='T:-500869684'), name='Bkth1;J (1/4) Ckth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=87, char_end=106, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10289)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:786380193'), value=Value(amount='jF SJ J(1/4', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=107, char_end=118, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10289)))], groundings=[], data_columns=None): {'Bkth1;J (1/4) Ckth1'},
#              AnchoredEntity(id=ID(id='E:151834407'), mentions=[Mention(id=ID(id='T:-2024477388'), name='Ds ThML Tkth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=25, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10366)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:2013261194'), value=Value(amount='0', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=41, char_end=42, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10366)))], groundings=[], data_columns=None): {'Ds ThML Tkth1'},
#              AnchoredEntity(id=ID(id='E:1889859998'), mentions=[Mention(id=ID(id='T:-2024477388'), name='Ds ThML Tkth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=25, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10438)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:2090706035'), value=Value(amount='XK Xkth1', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=43, char_end=51, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10438)))], groundings=[], data_columns=None): {'Ds ThML Tkth1'},
#              AnchoredEntity(id=ID(id='E:1175668440'), mentions=[Mention(id=ID(id='T:-2024477388'), name='Ds ThML Tkth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=25, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10513)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:2013261194'), value=Value(amount='0', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=41, char_end=42, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10513))), ValueDescription(id=ID(id='T:2090706035'), value=Value(amount='XK Xkth1', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=43, char_end=51, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10513)))], groundings=[], data_columns=None): {'Ds ThML Tkth1'},
#              AnchoredEntity(id=ID(id='R:1187951413'), mentions=[Mention(id=ID(id='T:1105667371'), name='s', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=39, char_end=40, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10653)))], text_descriptions=[TextDescription(id=ID(id='T:377892719'), description='Ds ThML Tkth1', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=25, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10653)))], value_descriptions=[], groundings=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7847759127616882, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10664)))], data_columns=None): {'Ds ThML Tkth1',
#               's'},
#              AnchoredEntity(id=ID(id='R:1656370629'), mentions=[Mention(id=ID(id='T:1294853518'), name='D D', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=18, char_end=21, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10731)))], text_descriptions=[TextDescription(id=ID(id='T:-567723067'), description='Tkth1 F S SD Th', grounding=[Grounding(grounding_text='Fluviral S/F', grounding_id='vo:0000866', source=[], score=0.8108342289924622, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10760)))], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=2, char_end=17, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10731)))], value_descriptions=[], groundings=[], data_columns=None): {'D D',
#               'Tkth1 F S SD Th'},
#              AnchoredEntity(id=ID(id='R:1834012256'), mentions=[Mention(id=ID(id='T:1164807764'), name='F', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=79, char_end=80, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10803)))], text_descriptions=[TextDescription(id=ID(id='T:-652016895'), description='F SJ Akth1;J Th', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=63, char_end=78, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10803)))], value_descriptions=[], groundings=[Grounding(grounding_text='rFP-RPV-H/F', grounding_id='vo:0004752', source=[], score=1.0, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10813)))], data_columns=None): {'F',
#               'F SJ Akth1;J Th'},
#              AnchoredEntity(id=ID(id='E:313771179'), mentions=[Mention(id=ID(id='T:-1523288128'), name='Tkth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=33, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10877)))], text_descriptions=[TextDescription(id=ID(id='T:1186998469'), description='0 XK Xkth1', grounding=[Grounding(grounding_text='Meruvax I', grounding_id='vo:0003109', source=[], score=0.7776500582695007, provenance=Provenance(method='SKEMA-TR-Embedding', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10899)))], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=41, char_end=51, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10877)))], value_descriptions=[], groundings=[], data_columns=None): {'0 XK Xkth1',
#               'Tkth1'},
#              AnchoredEntity(id=ID(id='E:-57352128'), mentions=[Mention(id=ID(id='T:-349006616'), name='Xkth1', extraction_source=TextExtraction(page=7, block=11, surrounding_passage='Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .', char_start=46, char_end=51, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10943)))], text_descriptions=[TextDescription(id=ID(id='T:-2024477388'), description='Ds ThML Tkth1', grounding=[], extraction_source=TextExtraction(page=7, block=11, surrounding_passage=None, char_start=25, char_end=38, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 10943)))], value_descriptions=[], groundings=[], data_columns=None): {'Ds ThML Tkth1',
#               'Xkth1'},
#              AnchoredEntity(id=ID(id='R:-463120844'), mentions=[Mention(id=ID(id='T:-1299977333'), name='XK    R', extraction_source=TextExtraction(page=8, block=0, surrounding_passage='4786 D. Baleanu et al. XK R .', char_start=23, char_end=30, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11013)))], text_descriptions=[TextDescription(id=ID(id='T:1024425322'), description='et al. XK', grounding=[], extraction_source=TextExtraction(page=8, block=0, surrounding_passage=None, char_start=16, char_end=25, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11013)))], value_descriptions=[], groundings=[], data_columns=None): {'XK    R',
#               'et al. XK'},
#              AnchoredEntity(id=ID(id='R:-1958896449'), mentions=[Mention(id=ID(id='T:-61037972'), name='Kth1', extraction_source=TextExtraction(page=9, block=3, surrounding_passage='XK : SP d36Th Dkth1 ; jF Sj Kth1 ( 1/4 ) S0 Th J ( 1/4 ) 0 .', char_start=27, char_end=31, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11099)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-1199471407'), value=Value(amount=') S0 Th J(1/4', grounding=[], extraction_source=TextExtraction(page=9, block=3, surrounding_passage=None, char_start=36, char_end=49, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11099)))], groundings=[], data_columns=None): {'Kth1'},
#              AnchoredEntity(id=ID(id='R:322594876'), mentions=[Mention(id=ID(id='T:472352507'), name='Fig. 5 The effect of parameters h2', extraction_source=TextExtraction(page=11, block=9, surrounding_passage='Fig. 5 The effect of parameters h2 ; x ; r2 ; jv , and sm on the number of infected individuals via the use of the fractional model ( 22 ) with a power-law kernel and a ( 1/4 ) 0:99 .', char_start=0, char_end=34, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf')), provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11190)))], text_descriptions=[], value_descriptions=[ValueDescription(id=ID(id='T:-2024553437'), value=Value(amount='5', grounding=[], extraction_source=TextExtraction(page=11, block=9, surrounding_passage=None, char_start=5, char_end=6, document_reference=ID(id='Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf'))), units=None, type=None, bounds=None, provenance=Provenance(method='Skema TR Pipeline rules', timestamp=datetime.datetime(2023, 9, 15, 20, 32, 29, 11190)))], groundings=[], data_columns=None): {'Fig. 5 The effect of parameters h2'}})

# %%
def revert_index(index):
	ret = defaultdict(list)
	for k, vs in index.items():
		for v in vs:
			ret[v].append(k)
	return ret

revert_index(load_variables('variables/page 7/eqn6.json'))
# Out:
# defaultdict(list,
#             {'β': ['β'],
#              'beta': ['β'],
#              'sigma': ['σ'],
#              'σ': ['σ'],
#              'r': ['r'],
#              'I_t': ['I_t'],
#              'I_{t}': ['I_t'],
#              'σ_it^t': ['σ_it^t'],
#              'σ_{it^{t}}': ['σ_it^t'],
#              't': ['t'],
#              'G': ['G'],
#              'S': ['S'],
#              'i': ['i'],
#              'p': ['p'],
#              'N': ['N'],
#              'S_{t}': ['S_t'],
#              'S_t': ['S_t'],
#              'I': ['I']})

# %%
from typing import List, Tuple
from sentence_transformers import SentenceTransformer, util


def align_texts(sources: List[str], targets: List[str], threshold: float, model) -> List[Tuple[str, str]]:

	with torch.no_grad():
		s_embs = model.encode(sources)
		t_embs = model.encode(targets)

	similarities = util.pytorch_cos_sim(s_embs, t_embs)

	indices = (similarities >= threshold).nonzero()

	ret = list()
	for ix in indices:
		ret.append((sources[ix[0]], targets[ix[1]], similarities[ix[0], ix[1]]))

	return ret

# %%
import dataclasses
from dataclasses import dataclass

@dataclass
class LinkedElement:
	element: str
	linked_str: str
	extraction: str
	score: float

def link_variables_to_extractions(equation_path, extractions_path):
	model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
	eqn = load_variables(equation_path)
	extractions = AttributeCollection.from_json(extractions_path)
	extractions_ix = extraction_index(extractions)

	inverted_eq = revert_index(eqn)
	invertex_ex = revert_index(extractions_ix)

	srcs = list(inverted_eq.keys())
	trgts = list(invertex_ex.keys())

	matches = align_texts(sources=srcs, targets=trgts, threshold=0.6, model=model)

	ret = list()
	for src_ix, tar_ix, sim in matches:
		for src in inverted_eq[src_ix]:
			for tgt in invertex_ex[tar_ix]:
				link = LinkedElement(
					element= src,
					extraction= tgt.model_dump(mode='json'),
					linked_str=tar_ix,
					score=sim.item()
				)
				ret.append(dataclasses.asdict(link))

	return json.dumps(ret, indent=2)

print(link_variables_to_extractions('variables/page 7/eqn6.json', 'extractions_page4.json'))
# Out:
# [
#   {
#     "element": "r",
#     "linked_str": "r",
#     "extraction": {
#       "id": {
#         "id": "R:954242467"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-704063786"
#           },
#           "name": "r",
#           "extraction_source": {
#             "page": 5,
#             "block": 7,
#             "surrounding_passage": "According to the CDa formula ( 1 ) , the expression 0 t represents the general left Caputo fractional derivative , and a shows the fractional order .\nAlso , to ensure that the above-mentioned fractional equations 1 are dimensionally matched on both sides , the coefficient r1a , including the auxiliary parameter r , is considered [ 41 ] .",
#             "char_start": 1028,
#             "char_end": 1029,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.002439"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-900029980"
#           },
#           "description": "auxiliary parameter",
#           "grounding": [
#             {
#               "grounding_text": "parameter estimation model",
#               "grounding_id": "apollosv:00000611",
#               "source": [],
#               "score": 0.7592645883560181,
#               "provenance": {
#                 "method": "SKEMA-TR-Embedding",
#                 "timestamp": "2023-09-15T20:32:29.00246"
#               }
#             }
#           ],
#           "extraction_source": {
#             "page": 5,
#             "block": 7,
#             "surrounding_passage": null,
#             "char_start": 1008,
#             "char_end": 1027,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.002439"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 1.0000003576278687
#   },
#   {
#     "element": "r",
#     "linked_str": "R0",
#     "extraction": {
#       "id": {
#         "id": "E:1694294597"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1435663954"
#           },
#           "name": "R0",
#           "extraction_source": {
#             "page": 6,
#             "block": 11,
#             "surrounding_passage": "From item 1 of Theorem 3.2 , it is obvious that a unique positive endemic equilibrium exists for R0 > 1 .\nWhen R0 < 1 , item 3 of Theorem 3.2 provides backward bifurcation possibility .",
#             "char_start": 96,
#             "char_end": 98,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.003094"
#           }
#         }
#       ],
#       "text_descriptions": [],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6879197955131531
#   },
#   {
#     "element": "r",
#     "linked_str": "R0",
#     "extraction": {
#       "id": {
#         "id": "E:-1573951117"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1786441733"
#           },
#           "name": "R0",
#           "extraction_source": {
#             "page": 9,
#             "block": 11,
#             "surrounding_passage": "According to these estimates , the mortality rate ( per day ) was obtained as n ( 1/4 ) 1 76:79 , while the birth rate ( per day ) was computed by b ( 1/4 ) 46 ; 381 .\nFor the given time duration of infected cases , R0 6:6361 was also estimated as the basic reproduction number .\nThe time was measured in the unit of days , and the system ( 22 ) was simulated applying the power-law , Mittag-Leffler , and exponential kernels in Figs .",
#             "char_start": 1442,
#             "char_end": 1444,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.004218"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1978203412"
#           },
#           "description": "given time duration of infected cases",
#           "grounding": [
#             {
#               "grounding_text": "probability of infection over time",
#               "grounding_id": "apollosv:00000530",
#               "source": [],
#               "score": 0.875653088092804,
#               "provenance": {
#                 "method": "SKEMA-TR-Embedding",
#                 "timestamp": "2023-09-15T20:32:29.004246"
#               }
#             }
#           ],
#           "extraction_source": {
#             "page": 9,
#             "block": 11,
#             "surrounding_passage": null,
#             "char_start": 1403,
#             "char_end": 1440,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.004218"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6879197955131531
#   },
#   {
#     "element": "r",
#     "linked_str": "R",
#     "extraction": {
#       "id": {
#         "id": "E:167301768"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:825972882"
#           },
#           "name": "R",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .\nNotice that the above general operators are linear , so we have CDa CDa CDa d d3Th 0 Th ( 1/4 ) k 0 t kf td Th th lg td Th t f td Th th l 0 t g td Th ; .",
#             "char_start": 140,
#             "char_end": 141,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.0083"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1088147632"
#           },
#           "description": "absolutely continuous function with _f 2 L1 Th",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 148,
#             "char_end": 194,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.0083"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 1.0000003576278687
#   },
#   {
#     "element": "r",
#     "linked_str": "XK    R",
#     "extraction": {
#       "id": {
#         "id": "R:-463120844"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1299977333"
#           },
#           "name": "XK    R",
#           "extraction_source": {
#             "page": 8,
#             "block": 0,
#             "surrounding_passage": "4786 D. Baleanu et al. XK R .",
#             "char_start": 23,
#             "char_end": 30,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.011013"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1024425322"
#           },
#           "description": "et al. XK",
#           "grounding": [],
#           "extraction_source": {
#             "page": 8,
#             "block": 0,
#             "surrounding_passage": null,
#             "char_start": 16,
#             "char_end": 25,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.011013"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6472443342208862
#   },
#   {
#     "element": "I_t",
#     "linked_str": "t",
#     "extraction": {
#       "id": {
#         "id": "E:1410321351"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-521600559"
#           },
#           "name": "t",
#           "extraction_source": {
#             "page": 4,
#             "block": 10,
#             "surrounding_passage": "Thus , the EQ .\n( 17 ) can be P td Th written as Z R tsup t sd Thds S tsup ( 1/4 ) S 0d Th exp ntsup th 0 R tsup d20Th t sd Thds th exp ntsup th 0 R R y tsup dy > 0 : 0 b exp ny th 0 t fd Thdf We can follow a similar strategy for the remaining equations in the system ( 15 ) to prove D td Th > 0 for all t > 0 .\nFor further assertion , consider that the initial conditions satisfy 0 < S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 6 P TD th .",
#             "char_start": 573,
#             "char_end": 574,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.001005"
#           }
#         }
#       ],
#       "text_descriptions": [],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6513166427612305
#   },
#   {
#     "element": "I_t",
#     "linked_str": "T",
#     "extraction": {
#       "id": {
#         "id": "E:-334254679"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1535608579"
#           },
#           "name": "T",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .\nNotice that the above general operators are linear , so we have CDa CDa CDa d d3Th 0 Th ( 1/4 ) k 0 t kf td Th th lg td Th t f td Th th l 0 t g td Th ; .",
#             "char_start": 204,
#             "char_end": 205,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1842213138"
#           },
#           "description": "general kernel loc",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 225,
#             "char_end": 243,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6513166427612305
#   },
#   {
#     "element": "t",
#     "linked_str": "t",
#     "extraction": {
#       "id": {
#         "id": "E:1410321351"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-521600559"
#           },
#           "name": "t",
#           "extraction_source": {
#             "page": 4,
#             "block": 10,
#             "surrounding_passage": "Thus , the EQ .\n( 17 ) can be P td Th written as Z R tsup t sd Thds S tsup ( 1/4 ) S 0d Th exp ntsup th 0 R tsup d20Th t sd Thds th exp ntsup th 0 R R y tsup dy > 0 : 0 b exp ny th 0 t fd Thdf We can follow a similar strategy for the remaining equations in the system ( 15 ) to prove D td Th > 0 for all t > 0 .\nFor further assertion , consider that the initial conditions satisfy 0 < S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 6 P TD th .",
#             "char_start": 573,
#             "char_end": 574,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.001005"
#           }
#         }
#       ],
#       "text_descriptions": [],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 1.0000001192092896
#   },
#   {
#     "element": "t",
#     "linked_str": "SUP T",
#     "extraction": {
#       "id": {
#         "id": "E:-1207175500"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-748193977"
#           },
#           "name": "SUP T",
#           "extraction_source": {
#             "page": 4,
#             "block": 10,
#             "surrounding_passage": "F G : Tsup ( 1/4 ) SUP T > 0 : D TD th > 0 Thus , Tsup > 0 .\nThe first equation of the model ( 15 ) leads to the following relation dS td Th ( 1/4 ) b nS td Th t td ThS td Th ( 1/4 ) b S td Th n th t td Th d Th ; d17Th dt d Th where t td Th ( 1/4 ) h1 I td Thth / A td Th th h2M td Th .",
#             "char_start": 16,
#             "char_end": 21,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.001089"
#           }
#         }
#       ],
#       "text_descriptions": [],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7846900224685669,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.001102"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6814061999320984
#   },
#   {
#     "element": "t",
#     "linked_str": "T",
#     "extraction": {
#       "id": {
#         "id": "E:-334254679"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1535608579"
#           },
#           "name": "T",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .\nNotice that the above general operators are linear , so we have CDa CDa CDa d d3Th 0 Th ( 1/4 ) k 0 t kf td Th th lg td Th t f td Th th l 0 t g td Th ; .",
#             "char_start": 204,
#             "char_end": 205,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1842213138"
#           },
#           "description": "general kernel loc",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 225,
#             "char_end": 243,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 1.0000001192092896
#   },
#   {
#     "element": "t",
#     "linked_str": "d",
#     "extraction": {
#       "id": {
#         "id": "R:-1822270571"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1157852791"
#           },
#           "name": "d",
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": "Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .",
#             "char_start": 36,
#             "char_end": 37,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009857"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1731739390"
#           },
#           "description": "Th d d Th ds",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": null,
#             "char_start": 23,
#             "char_end": 35,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009857"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6234027743339539
#   },
#   {
#     "element": "G",
#     "linked_str": "g",
#     "extraction": {
#       "id": {
#         "id": "R:-1270356868"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:471962541"
#           },
#           "name": "g",
#           "extraction_source": {
#             "page": 3,
#             "block": 8,
#             "surrounding_passage": "Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .",
#             "char_start": 18,
#             "char_end": 19,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996283"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1769299146"
#           },
#           "description": "Z T T CDa d12Th",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 8,
#             "surrounding_passage": null,
#             "char_start": 2,
#             "char_end": 17,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996283"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Education-Subcommittee G",
#           "grounding_id": "ncit:C19510",
#           "source": [],
#           "score": 1.0,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:28.996295"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999998211860657
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-1106686363"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-2101005978"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 3,
#             "block": 6,
#             "surrounding_passage": "Z T d Th ds ; d9Th tDa f sd ThKR s t Tf td Th ( 1/4 ) d dt t and the right-sided Riemann-Liouville fractional integral would be described as .",
#             "char_start": 32,
#             "char_end": 33,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996069"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-493595611"
#           },
#           "description": "tDa f sd ThKR",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 6,
#             "surrounding_passage": null,
#             "char_start": 18,
#             "char_end": 31,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996069"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:28.996081"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-1629500135"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1747195779"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 3,
#             "block": 8,
#             "surrounding_passage": "Z Z T T CDa d12Th g sd ThsDa f sd Th0 s g sd Thds ( 1/4 ) Tf sd Thds : 0 0 Now , three particular cases are introduced here according to the recent definitions .\nFirst , the general kernel KL td Th is set as KL td Th ( 1/4 ) ta C 1a d Th ; thus , the power function ML td Th ( 1/4 ) ta1 C ad Th constitutes the associated kernel for the integral operator ( 7 ) .",
#             "char_start": 38,
#             "char_end": 39,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996195"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:471952483"
#           },
#           "description": "sd ThsDa f sd Th0",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 8,
#             "surrounding_passage": null,
#             "char_start": 20,
#             "char_end": 37,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:28.996195"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:28.996206"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:1598892848"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:889411511"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .",
#             "char_start": 34,
#             "char_end": 35,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008072"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-2092837753"
#           },
#           "description": "0Da f sd ThKL t",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 18,
#             "char_end": 33,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008072"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.008087"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-443689058"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:2010071284"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 6,
#             "block": 15,
#             "surrounding_passage": "The next equation where F S td Th d Th :( 1/4 ) r1a b nS td Th t td ThS td Th is the result of replacing t by tkth1 in the Eq .\n( 28 ) Z TKTH1 F S SD Th D D Th Ds : d29Th Skth1 ( 1/4 ) S0 th ThML Tkth1 s 0 .",
#             "char_start": 413,
#             "char_end": 414,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.00941"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1591949519"
#           },
#           "description": "ThML Tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 6,
#             "block": 15,
#             "surrounding_passage": null,
#             "char_start": 402,
#             "char_end": 412,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.00941"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.00942"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-1041985397"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-38577514"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 0,
#             "surrounding_passage": "A new comparative study on the general fractional model of COVID-19 4785 th s tj bFkth1 sd Th S tjth1 s .",
#             "char_start": 104,
#             "char_end": 105,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009754"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:2062042911"
#           },
#           "description": "bFkth1 sd Th S tjth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 0,
#             "surrounding_passage": null,
#             "char_start": 83,
#             "char_end": 103,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009754"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.009767"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:71221897"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1822149027"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": "Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .",
#             "char_start": 56,
#             "char_end": 57,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010008"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1731035597"
#           },
#           "description": "ThML tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": null,
#             "char_start": 45,
#             "char_end": 55,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010008"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010019"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-946395320"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:778672615"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": "Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .",
#             "char_start": 79,
#             "char_end": 80,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010138"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:656199421"
#           },
#           "description": "bFkth1 sd ThML tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": null,
#             "char_start": 58,
#             "char_end": 78,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010138"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010149"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "S",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:1187951413"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1105667371"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 11,
#             "surrounding_passage": "Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .",
#             "char_start": 39,
#             "char_end": 40,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010653"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:377892719"
#           },
#           "description": "Ds ThML Tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 11,
#             "surrounding_passage": null,
#             "char_start": 25,
#             "char_end": 38,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010653"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010664"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.9999992251396179
#   },
#   {
#     "element": "p",
#     "linked_str": "b",
#     "extraction": {
#       "id": {
#         "id": "E:-957951765"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1067984383"
#           },
#           "name": "b",
#           "extraction_source": {
#             "page": 4,
#             "block": 4,
#             "surrounding_passage": "The infected people with clinically symptomatic or without clinical symptoms , as well as the infected individuals of seafood markets I td Th ; A td Th ; M td Th d Th can infect the susceptible people to the disease , which is shown as t td Th .\nFor susceptible individuals , the corresponding birth rate is b , and the human mortality rate can be measured by n. Healthy people would become infectious after exposure to the infected and asymptomatically infected individuals at the rate h1 , where as the transmissibility factor is denoted by / .\nThe number of people who are affected as a result of visiting seafood markets is increased by h2 .",
#             "char_start": 302,
#             "char_end": 303,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.000011"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1524698050"
#           },
#           "description": "corresponding birth rate",
#           "grounding": [
#             {
#               "grounding_text": "Noise Equivalent Count Rate",
#               "grounding_id": "ncit:C94941",
#               "source": [],
#               "score": 0.7655113339424133,
#               "provenance": {
#                 "method": "SKEMA-TR-Embedding",
#                 "timestamp": "2023-09-15T20:32:29.000038"
#               }
#             }
#           ],
#           "extraction_source": {
#             "page": 4,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 274,
#             "char_end": 298,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.000011"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "AIDSVAX B/B",
#           "grounding_id": "vo:0000405",
#           "source": [],
#           "score": 0.8989673256874084,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.000022"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6303893327713013
#   },
#   {
#     "element": "p",
#     "linked_str": "b",
#     "extraction": {
#       "id": {
#         "id": "R:458610627"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:560977112"
#           },
#           "name": "b",
#           "extraction_source": {
#             "page": 5,
#             "block": 1,
#             "surrounding_passage": "d Th .\nHence , n 1 ent Furthermore , either P td Th tends asymptomatically toward b n or the solution enters Z in a finite time if we have P 0d Th < b n and sithsa M 0d Th < b .\nThis means that all the solutions in R7th are n sm attracted by the region given by Z. h .",
#             "char_start": 563,
#             "char_end": 564,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.002251"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1981491033"
#           },
#           "description": "sithsa M 0d Th <",
#           "grounding": [],
#           "extraction_source": {
#             "page": 5,
#             "block": 1,
#             "surrounding_passage": null,
#             "char_start": 546,
#             "char_end": 562,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.002251"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "AIDSVAX B/B",
#           "grounding_id": "vo:0000405",
#           "source": [],
#           "score": 0.8989673256874084,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.002265"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6303893327713013
#   },
#   {
#     "element": "p",
#     "linked_str": "b",
#     "extraction": {
#       "id": {
#         "id": "E:-656629184"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1776527982"
#           },
#           "name": "b",
#           "extraction_source": {
#             "page": 9,
#             "block": 11,
#             "surrounding_passage": "According to these results , one can see that the best fractional order is 0:99 for all three cases .\nFig. 4 displays the fractional simulations by considering the ( a ) power-law , ( b ) Mittag-Leffler , and ( c ) exponential kernels versus the real reported cases of COVID-19 in China .\nThe results illustrate the improvement which is made by applying the new general fractional model to follow the real data better than the classical integer-order model .",
#             "char_start": 2199,
#             "char_end": 2200,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.004819"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-585538958"
#           },
#           "description": ") power-law",
#           "grounding": [],
#           "extraction_source": {
#             "page": 9,
#             "block": 11,
#             "surrounding_passage": null,
#             "char_start": 2185,
#             "char_end": 2196,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.004819"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "AIDSVAX B/B",
#           "grounding_id": "vo:0000405",
#           "source": [],
#           "score": 0.8989673256874084,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.004832"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6303893327713013
#   },
#   {
#     "element": "p",
#     "linked_str": "P",
#     "extraction": {
#       "id": {
#         "id": "E:939845203"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1157437001"
#           },
#           "name": "P",
#           "extraction_source": {
#             "page": 4,
#             "block": 8,
#             "surrounding_passage": "D TD th ( 1/4 ) s TD th ; v TD th ; i TD th ; A TD th ; K TD th ; U TD th ; R TD th ; M TD th D th ; D th P 0 Be the Nonand D 0d th ( 1/4 ) S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 ; M0 negative initial state vector .\nThen the model ( 15 ) has a nonnegative solution for any time t > 0 .",
#             "char_start": 96,
#             "char_end": 97,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.000594"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:175687440"
#           },
#           "description": "Nonand D 0d",
#           "grounding": [
#             {
#               "grounding_text": "Meruvax I",
#               "grounding_id": "vo:0003109",
#               "source": [],
#               "score": 0.7801608443260193,
#               "provenance": {
#                 "method": "SKEMA-TR-Embedding",
#                 "timestamp": "2023-09-15T20:32:29.000621"
#               }
#             }
#           ],
#           "extraction_source": {
#             "page": 4,
#             "block": 8,
#             "surrounding_passage": null,
#             "char_start": 107,
#             "char_end": 118,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
# ...
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:1598892848"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:889411511"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .",
#             "char_start": 34,
#             "char_end": 35,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008072"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-2092837753"
#           },
#           "description": "0Da f sd ThKL t",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 18,
#             "char_end": 33,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008072"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.008087"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-443689058"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:2010071284"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 6,
#             "block": 15,
#             "surrounding_passage": "The next equation where F S td Th d Th :( 1/4 ) r1a b nS td Th t td ThS td Th is the result of replacing t by tkth1 in the Eq .\n( 28 ) Z TKTH1 F S SD Th D D Th Ds : d29Th Skth1 ( 1/4 ) S0 th ThML Tkth1 s 0 .",
#             "char_start": 413,
#             "char_end": 414,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.00941"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1591949519"
#           },
#           "description": "ThML Tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 6,
#             "block": 15,
#             "surrounding_passage": null,
#             "char_start": 402,
#             "char_end": 412,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.00941"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.00942"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-1041985397"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-38577514"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 0,
#             "surrounding_passage": "A new comparative study on the general fractional model of COVID-19 4785 th s tj bFkth1 sd Th S tjth1 s .",
#             "char_start": 104,
#             "char_end": 105,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009754"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:2062042911"
#           },
#           "description": "bFkth1 sd Th S tjth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 0,
#             "surrounding_passage": null,
#             "char_start": 83,
#             "char_end": 103,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.009754"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.009767"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:71221897"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-1822149027"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": "Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .",
#             "char_start": 56,
#             "char_end": 57,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010008"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:1731035597"
#           },
#           "description": "ThML tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": null,
#             "char_start": 45,
#             "char_end": 55,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010008"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010019"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:-946395320"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:778672615"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": "Z Z tkth1 tkth1 F S sd Th d d Th ds d Th ds ; ThML tkth1 s bFkth1 sd ThML tkth1 s 0 0 d30Th d Th is piecewise linwhere the interpolation polynomial bF Skth1 sd Th .",
#             "char_start": 79,
#             "char_end": 80,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010138"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:656199421"
#           },
#           "description": "bFkth1 sd ThML tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 2,
#             "surrounding_passage": null,
#             "char_start": 58,
#             "char_end": 78,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010138"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010149"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "s",
#     "extraction": {
#       "id": {
#         "id": "R:1187951413"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1105667371"
#           },
#           "name": "s",
#           "extraction_source": {
#             "page": 7,
#             "block": 11,
#             "surrounding_passage": "Z Tkth1 F S SD Th D D th Ds ThML Tkth1 s 0 XK Xkth1 ; d32Th F SJ Akth1 ;J Th F Sjth1 Bkth1 ;J ( 1/4 ) Ckth1 ; jF SJ J ( 1/4 ) 0 J ( 1/4 ) 0 .",
#             "char_start": 39,
#             "char_end": 40,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010653"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:377892719"
#           },
#           "description": "Ds ThML Tkth1",
#           "grounding": [],
#           "extraction_source": {
#             "page": 7,
#             "block": 11,
#             "surrounding_passage": null,
#             "char_start": 25,
#             "char_end": 38,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.010653"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [
#         {
#           "grounding_text": "Meruvax I",
#           "grounding_id": "vo:0003109",
#           "source": [],
#           "score": 0.7847759127616882,
#           "provenance": {
#             "method": "SKEMA-TR-Embedding",
#             "timestamp": "2023-09-15T20:32:29.010664"
#           }
#         }
#       ],
#       "data_columns": null
#     },
#     "score": 0.6580480933189392
#   },
#   {
#     "element": "S_t",
#     "linked_str": "t",
#     "extraction": {
#       "id": {
#         "id": "E:1410321351"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:-521600559"
#           },
#           "name": "t",
#           "extraction_source": {
#             "page": 4,
#             "block": 10,
#             "surrounding_passage": "Thus , the EQ .\n( 17 ) can be P td Th written as Z R tsup t sd Thds S tsup ( 1/4 ) S 0d Th exp ntsup th 0 R tsup d20Th t sd Thds th exp ntsup th 0 R R y tsup dy > 0 : 0 b exp ny th 0 t fd Thdf We can follow a similar strategy for the remaining equations in the system ( 15 ) to prove D td Th > 0 for all t > 0 .\nFor further assertion , consider that the initial conditions satisfy 0 < S0 ; v0 ; i0 ; A0 ; K0 ; U0 ; R0 6 P TD th .",
#             "char_start": 573,
#             "char_end": 574,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.001005"
#           }
#         }
#       ],
#       "text_descriptions": [],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6336206793785095
#   },
#   {
#     "element": "S_t",
#     "linked_str": "T",
#     "extraction": {
#       "id": {
#         "id": "E:-334254679"
#       },
#       "mentions": [
#         {
#           "id": {
#             "id": "T:1535608579"
#           },
#           "name": "T",
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": "Z t d Th ds ; d2Th 0Da f sd ThKL t s t f td Th ( 1/4 ) d dt 0 fractional derivative , in which a 2 0 ; 1d Th is the order of f : 0 ; th1 ( 1/2 ) Th !\nR is an absolutely continuous function with _ f 2 L1 Th ; 0 6 t 6 T < th1 , and KL is a general kernel loc 0 ; th1d function that is non negative and locally integrable on Rth .\nNotice that the above general operators are linear , so we have CDa CDa CDa d d3Th 0 Th ( 1/4 ) k 0 t kf td Th th lg td Th t f td Th th l 0 t g td Th ; .",
#             "char_start": 204,
#             "char_end": 205,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "text_descriptions": [
#         {
#           "id": {
#             "id": "T:-1842213138"
#           },
#           "description": "general kernel loc",
#           "grounding": [],
#           "extraction_source": {
#             "page": 3,
#             "block": 4,
#             "surrounding_passage": null,
#             "char_start": 225,
#             "char_end": 243,
#             "document_reference": {
#               "id": "Anewcomparativestudyonthegeneralfractional modelofCOVID-19withisolationandquarantine effects.pdf"
#             }
#           },
#           "provenance": {
#             "method": "Skema TR Pipeline rules",
#             "timestamp": "2023-09-15T20:32:29.008136"
#           }
#         }
#       ],
#       "value_descriptions": [],
#       "groundings": [],
#       "data_columns": null
#     },
#     "score": 0.6336206793785095
#   }
# ]
